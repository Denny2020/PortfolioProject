# %% [markdown]
# # Data Analysis of Kaggle Movie dataset using python.

# %% [markdown]
# In this project, we will use python libraries pandas, numpy to analyze the dataset, then use matplotlib and seaborn to visualize our analysis. We will try to find the correlations between different variables of the dataset, such as the budget, votes,gross earnings, ratings etc.

# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

# %%
df = pd.read_csv('movies.csv')
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# name - 0%
# rating - 1%
# genre - 0%
# year - 0%
# released - 0%
# score - 0%
# votes - 0%
# director - 0%
# writer - 0%
# star - 0%
# country - 0%
# budget - 28%
# gross - 2%
# company - 0%
# runtime - 0%

# %%
df['budget']
# Out:
# 0       19000000.0
# 1        4500000.0
# 2       18000000.0
# 3        3500000.0
# 4        6000000.0
#            ...
# 7663        7000.0
# 7664           NaN
# 7665       58750.0
# 7666       15000.0
# 7667           NaN
# Name: budget, Length: 7668, dtype: float64

# %%
df[df["budget"].isnull()]
# Out:
#                   name     rating   genre  year  \
# 16                Fame          R   Drama  1980
# 19          Stir Crazy          R  Comedy  1980
# 24        Urban Cowboy         PG   Drama  1980
# 25      Altered States          R  Horror  1980
# 26     Little Darlings          R  Comedy  1980
# ...                ...        ...     ...   ...
# 7657              Leap        NaN   Drama  2020
# 7659         I Am Fear  Not Rated  Horror  2020
# 7660  Aloha Surf Hotel        NaN  Comedy  2020
# 7664       Dream Round        NaN  Comedy  2020
# 7667         Tee em el        NaN  Horror  2020
#
#                                 released  score    votes            director  \
# 16          May 16, 1980 (United States)    6.6  21000.0         Alan Parker
# 19     December 12, 1980 (United States)    6.8  26000.0      Sidney Poitier
# 24          June 6, 1980 (United States)    6.4  14000.0       James Bridges
# ...

# %%
df["budget"].isna().sum()
# Out:
# 2171

# %%
df2 = df.dropna()
df2.head()
# Out:
#                                              name rating      genre  year  \
# 0                                     The Shining      R      Drama  1980
# 1                                 The Blue Lagoon      R  Adventure  1980
# 2  Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                       Airplane!     PG     Comedy  1980
# 4                                      Caddyshack      R     Comedy  1980
#
#                         released  score      votes         director  \
# 0  June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1   July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2  June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3   July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4  July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
#
#                     writer            star         country      budget  \
# ...

# %%
df2["budget"].isna().sum()
# Out:
# 0

# %%
# Data Types for our columns

print(df2.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget      float64
# gross       float64
# company      object
# runtime     float64
# dtype: object

# %%
# convert budget and gross columns from float to int data type
df2["budget"] = df2["budget"].astype('int64')
df2["gross"] = df2["gross"].astype('int64')

# %%
print(df2.dtypes)
# Out:
# name         object
# rating       object
# genre        object
# year          int64
# released     object
# score       float64
# votes       float64
# director     object
# writer       object
# star         object
# country      object
# budget        int64
# gross         int64
# company      object
# runtime     float64
# dtype: object

# %%
df['year_corr'] = df['released'].astype(str).str[:5]

# %%
df['year_corr']
# Out:
# 0       June
# 1       July
# 2       June
# 3       July
# 4       July
#         ...
# 7663    Octob
# 7664    Febru
# 7665    April
# 7666    Octob
# 7667    Augus
# Name: year_corr, Length: 7668, dtype: object

# %%
#sort data using gross column in descending order
df2.sort_values(by=['gross'],inplace = False, ascending = False).head()
# Out:
#                                             name rating   genre  year  \
# 5445                                      Avatar  PG-13  Action  2009
# 7445                           Avengers: Endgame  PG-13  Action  2019
# 3045                                     Titanic  PG-13   Drama  1997
# 6663  Star Wars: Episode VII - The Force Awakens  PG-13  Action  2015
# 7244                      Avengers: Infinity War  PG-13  Action  2018
#
#                                released  score      votes       director  \
# 5445  December 18, 2009 (United States)    7.8  1100000.0  James Cameron
# 7445     April 26, 2019 (United States)    8.4   903000.0  Anthony Russo
# 3045  December 19, 1997 (United States)    7.8  1100000.0  James Cameron
# 6663  December 18, 2015 (United States)    7.8   876000.0    J.J. Abrams
# 7244     April 27, 2018 (United States)    8.4   897000.0  Anthony Russo
#
#                   writer               star        country       budget  \
# ...

# %%
# Adjust the display to maximum
pd.set_option('display.max_rows', None)

# %%
df2['company'].drop_duplicates().sort_values(ascending= False)
# Out:
# 7129                                              thefyzz
# 5664                                          micro_scope
# 4007                                             i5 Films
# 6793                                           i am OTHER
# 6420                                                 erbp
# 3776                                       double A Films
# 3330                          Zucker Brothers Productions
# 146                                      Zoetrope Studios
# 2213                                   Zeta Entertainment
# 3698                              Zentropa Entertainments
# 1180                                 Zenith Entertainment
# 5180                                      Zazen Produções
# 1321                             Zanuck/Brown Productions
# 1329                          Zacharias-Buhai Productions
# 789                             Young Sung Production Co.
# 5125                           Young Hannibal Productions
# ...

# %%
# scatter plot with budget vs gross
# This is to find out if they are correlated.

plt.scatter(x= df2['budget'],y=df2['gross'])
plt.title('Budget vs Gross Earning')

plt.xlabel('Gross Earning')
plt.ylabel('Budget for firm')

plt.show()

# %%
#Plot budget vs Gross using seaborn

sns.regplot(x="gross", y="budget", data=df2, scatter_kws = {'color':'red'},line_kws = {'color':'blue'})
# Out:
# <AxesSubplot:xlabel='gross', ylabel='budget'>

# %%
#Plot votes vs Gross using seaborn

sns.regplot(x="gross", y="votes", data=df2, scatter_kws = {'color':'red'},line_kws = {'color':'green'})
# Out:
# <AxesSubplot:xlabel='gross', ylabel='votes'>

# %%
#Plot budget vs votes using seaborn

sns.regplot(x="votes", y="budget", data=df2, scatter_kws = {'color':'red'},line_kws = {'color':'blue'})
# Out:
# <AxesSubplot:xlabel='votes', ylabel='budget'>

# %%
#let start looking at correlation

# %%
df2.corr(method = 'pearson') # pearson, kendall, spearman
# Out:
#              year     score     votes    budget     gross   runtime
# year     1.000000  0.056386  0.206021  0.327722  0.274321  0.075077
# score    0.056386  1.000000  0.474256  0.072001  0.222556  0.414068
# votes    0.206021  0.474256  1.000000  0.439675  0.614751  0.352303
# budget   0.327722  0.072001  0.439675  1.000000  0.740247  0.318695
# gross    0.274321  0.222556  0.614751  0.740247  1.000000  0.275796
# runtime  0.075077  0.414068  0.352303  0.318695  0.275796  1.000000

# %%
#visualise the corr
correlation_matrix = df2.corr(method = 'pearson')
sns.heatmap(correlation_matrix,annot = True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
# Note, the previous heatmap shows correlations for only numeric columns but we have other columns such as company,
#rating,genre. Lets convert these data type from objects to category in order to visualize their correlation with 
# budget,gross and votes.

df_numerized = df2


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized.head()
# Out:
#    name  rating  genre  year  released  score      votes  director  writer  \
# 0  4692       6      6  1980      1304    8.4   927000.0      1795    2832
# 1  3929       6      1  1980      1127    5.8    65000.0      1578    1158
# 2  3641       4      0  1980      1359    8.7  1200000.0       757    1818
# 3   204       4      4  1980      1127    7.7   221000.0       889    1413
# 4   732       6      4  1980      1170    7.3   108000.0       719     351
#
#    star  country      budget        gross  company  runtime
# 0   699       46  19000000.0   46998772.0     1426    146.0
# 1   214       47   4500000.0   58853106.0      452    104.0
# 2  1157       47  18000000.0  538375067.0      945    124.0
# 3  1474       47   3500000.0   83453539.0     1108     88.0
# 4   271       47   6000000.0   39846344.0     1083     98.0

# %%
correlation_matrix = df_numerized.corr(method = 'pearson')
sns.heatmap(correlation_matrix,annot = True)

plt.title('Correlation Matrix for Numeric Features')

plt.xlabel('Movie Features')
plt.ylabel('Movie Features')

plt.show()

# %%
correlation_mat = df_numerized.corr(method = 'pearson')

# %%
corr_pair = correlation_mat.unstack()
corr_pair
# Out:
# name      name        1.000000
#           rating     -0.029234
#           genre       0.010996
#           year        0.025542
#           released   -0.006152
#           score       0.014450
#           votes       0.012615
#           director    0.015246
#           writer      0.012880
#           star       -0.006882
#           country    -0.025490
#           budget      0.023392
#           gross       0.005639
#           company     0.021697
#           runtime     0.010850
# rating    name       -0.029234
#           rating      1.000000
#           genre       0.147796
#           year        0.019499
#           released    0.018083
#           score       0.065983
#           votes       0.006031
#           director    0.014656
#           writer     -0.003149
#           star        0.009196
#           country     0.008230
#           budget     -0.203946
#           gross      -0.181906
#           company    -0.092357
#           runtime     0.140792
# ...

# %%
sorted_pair = corr_pair.sort_values()
sorted_pair
# Out:
# budget    genre      -0.368523
# genre     budget     -0.368523
#           gross      -0.244101
# gross     genre      -0.244101
# budget    rating     -0.203946
# rating    budget     -0.203946
#           gross      -0.181906
# gross     rating     -0.181906
# genre     votes      -0.135990
# votes     genre      -0.135990
# company   rating     -0.092357
# rating    company    -0.092357
# genre     year       -0.073167
# year      genre      -0.073167
# genre     company    -0.071334
# company   genre      -0.071334
# year      country    -0.066748
# country   year       -0.066748
# genre     runtime    -0.059237
# runtime   genre      -0.059237
# country   score      -0.043051
# score     country    -0.043051
# budget    writer     -0.039466
# writer    budget     -0.039466
# director  year       -0.038354
# year      director   -0.038354
# writer    gross      -0.035885
# gross     writer     -0.035885
# country   runtime    -0.034477
# runtime   country    -0.034477
# ...

# %%
high_corr = sorted_pair[(sorted_pair) > 0.5]
high_corr
# Out:
# votes     gross       0.614751
# gross     votes       0.614751
#           budget      0.740247
# budget    gross       0.740247
# name      name        1.000000
# director  director    1.000000
# gross     gross       1.000000
# budget    budget      1.000000
# country   country     1.000000
# star      star        1.000000
# writer    writer      1.000000
# votes     votes       1.000000
# score     score       1.000000
# released  released    1.000000
# year      year        1.000000
# genre     genre       1.000000
# rating    rating      1.000000
# company   company     1.000000
# runtime   runtime     1.000000
# dtype: float64

# %%
# Summary-- Votes and budget has the highest correlation to gross earnings.

# %%
#let save df2 to csv file for futher visualisation on Tableau.

df2.to_csv('Normalised_data.csv',index=False)
